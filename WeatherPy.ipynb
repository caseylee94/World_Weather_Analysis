# %%
# Import the dependencies

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 649

# %%
# Import the requests library
import requests

# import the API key
from config import weather_api_key

# %%
# Starting URl for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9238727c7158ceca2ba4693bf673118a

# %%
# Import the time linrary

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging

print("Beginning data retrieval     ")
print("-----------------------------")


# Create counters

record_count = 1
set_count = 1
# Out:
# Beginning data retrieval
# -----------------------------

# %%
# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    # Log the URL, record, and et numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    
    record_count += 1
    
# Run an API request for each of the cities

    try:
        # parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
                # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | shieli
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | joao pinheiro
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | kotido
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | yuncheng
# Processing Record 12 of Set 1 | awbari
# Processing Record 13 of Set 1 | saint-joseph
# Processing Record 14 of Set 1 | milkovo
# Processing Record 15 of Set 1 | morros
# Processing Record 16 of Set 1 | qasigiannguit
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | kismayo
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | changji
# Processing Record 24 of Set 1 | hirara
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | suoyarvi
# Processing Record 27 of Set 1 | oyama
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | darnah
# Processing Record 31 of Set 1 | esquipulas palo gordo
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | novyy urgal
# Processing Record 34 of Set 1 | bairiki
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 40 of Set 1 | gijon
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | port shepstone
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | cururupu
# Processing Record 46 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 1 | kingseat
# Processing Record 48 of Set 1 | jampur
# Processing Record 49 of Set 1 | jinchang
# Processing Record 50 of Set 1 | campbellsville
# Processing Record 1 of Set 2 | kudahuvadhoo
# Processing Record 2 of Set 2 | praya
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | nanortalik
# Processing Record 7 of Set 2 | hobyo
# Processing Record 8 of Set 2 | naujamiestis
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | black river
# Processing Record 13 of Set 2 | cabinda
# Processing Record 14 of Set 2 | bukan
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | seddon
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | kysyl-syr
# Processing Record 21 of Set 2 | paternion
# Processing Record 22 of Set 2 | umm lajj
# Processing Record 23 of Set 2 | kargat
# Processing Record 24 of Set 2 | bardiyah
# Processing Record 25 of Set 2 | odweyne
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | grindavik
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | tura
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | kidal
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | tupelo
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | la ronge
# Processing Record 41 of Set 2 | deer lake
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | majene
# Processing Record 44 of Set 2 | santa lucia
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | macau
# Processing Record 48 of Set 2 | kloulklubed
# Processing Record 49 of Set 2 | puerto madryn
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | quatre cocos
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | imbituba
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | manokwari
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | tombouctou
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | upington
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | kieta
# Processing Record 20 of Set 3 | rawson
# Processing Record 21 of Set 3 | dauriya
# Processing Record 22 of Set 3 | tecoanapa
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | portland
# Processing Record 25 of Set 3 | caravelas
# Processing Record 26 of Set 3 | tarko-sale
# Processing Record 27 of Set 3 | sioux lookout
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | nyagan
# Processing Record 30 of Set 3 | opelousas
# Processing Record 31 of Set 3 | halifax
# Processing Record 32 of Set 3 | richards bay
# Processing Record 33 of Set 3 | kota belud
# Processing Record 34 of Set 3 | paramithia
# City not found. Skipping...
# Processing Record 35 of Set 3 | namibe
# Processing Record 36 of Set 3 | tobol
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | brae
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | muchkapskiy
# Processing Record 41 of Set 3 | makakilo city
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | contamana
# Processing Record 44 of Set 3 | maputo
# Processing Record 45 of Set 3 | nuuk
# Processing Record 46 of Set 3 | zholymbet
# Processing Record 47 of Set 3 | flin flon
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | thousand oaks
# Processing Record 1 of Set 4 | matay
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | kargopol
# Processing Record 5 of Set 4 | lukulu
# Processing Record 6 of Set 4 | devils lake
# Processing Record 7 of Set 4 | hvide sande
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | clyde river
# Processing Record 12 of Set 4 | porto belo
# Processing Record 13 of Set 4 | nizhniy kuranakh
# Processing Record 14 of Set 4 | anadyr
# Processing Record 15 of Set 4 | vostok
# Processing Record 16 of Set 4 | vagur
# Processing Record 17 of Set 4 | monrovia
# Processing Record 18 of Set 4 | comodoro rivadavia
# Processing Record 19 of Set 4 | bonga
# Processing Record 20 of Set 4 | cayenne
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | brownwood
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | cuauhtemoc
# Processing Record 26 of Set 4 | itoman
# Processing Record 27 of Set 4 | liverpool
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | nantucket
# Processing Record 31 of Set 4 | makinsk
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | auki
# Processing Record 34 of Set 4 | san juan
# Processing Record 35 of Set 4 | constitucion
# Processing Record 36 of Set 4 | lata
# Processing Record 37 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 38 of Set 4 | aripuana
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | zambezi
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | upernavik
# Processing Record 43 of Set 4 | gat
# Processing Record 44 of Set 4 | aksarka
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | prado
# Processing Record 47 of Set 4 | araouane
# Processing Record 48 of Set 4 | camargo
# Processing Record 49 of Set 4 | ukiah
# Processing Record 50 of Set 4 | yuanping
# Processing Record 1 of Set 5 | poum
# Processing Record 2 of Set 5 | harda
# Processing Record 3 of Set 5 | miri
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | port blair
# Processing Record 6 of Set 5 | nara
# Processing Record 7 of Set 5 | harper
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | yerofey pavlovich
# Processing Record 11 of Set 5 | le port
# Processing Record 12 of Set 5 | manggar
# Processing Record 13 of Set 5 | taltal
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | callaway
# Processing Record 16 of Set 5 | sri aman
# Processing Record 17 of Set 5 | kaset sombun
# Processing Record 18 of Set 5 | pevek
# Processing Record 19 of Set 5 | kapaa
# Processing Record 20 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 5 | pacific grove
# Processing Record 22 of Set 5 | nouakchott
# Processing Record 23 of Set 5 | shingu
# Processing Record 24 of Set 5 | tinde
# Processing Record 25 of Set 5 | gravdal
# Processing Record 26 of Set 5 | holly hill
# Processing Record 27 of Set 5 | stabat
# Processing Record 28 of Set 5 | jefferson city
# Processing Record 29 of Set 5 | taoudenni
# Processing Record 30 of Set 5 | bambous virieux
# Processing Record 31 of Set 5 | harwich
# Processing Record 32 of Set 5 | las varas
# Processing Record 33 of Set 5 | hasaki
# Processing Record 34 of Set 5 | batemans bay
# Processing Record 35 of Set 5 | hami
# Processing Record 36 of Set 5 | nha trang
# Processing Record 37 of Set 5 | homer
# Processing Record 38 of Set 5 | nushki
# Processing Record 39 of Set 5 | georgetown
# Processing Record 40 of Set 5 | usinsk
# Processing Record 41 of Set 5 | rumoi
# Processing Record 42 of Set 5 | urumqi
# Processing Record 43 of Set 5 | cusset
# Processing Record 44 of Set 5 | salalah
# Processing Record 45 of Set 5 | kogon
# Processing Record 46 of Set 5 | atambua
# Processing Record 47 of Set 5 | palmer
# Processing Record 48 of Set 5 | tessaoua
# Processing Record 49 of Set 5 | zhongshu
# Processing Record 50 of Set 5 | yerbogachen
# Processing Record 1 of Set 6 | malartic
# Processing Record 2 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 6 | afsin
# Processing Record 4 of Set 6 | aklavik
# Processing Record 5 of Set 6 | gazli
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | weligama
# Processing Record 8 of Set 6 | kangaatsiaq
# Processing Record 9 of Set 6 | tiksi
# Processing Record 10 of Set 6 | kathmandu
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | hambantota
# Processing Record 13 of Set 6 | chapleau
# Processing Record 14 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 6 | morgan city
# Processing Record 16 of Set 6 | namatanai
# Processing Record 17 of Set 6 | kinston
# Processing Record 18 of Set 6 | east wenatchee bench
# Processing Record 19 of Set 6 | talnakh
# Processing Record 20 of Set 6 | kamskiye polyany
# Processing Record 21 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 6 | trinidad
# Processing Record 23 of Set 6 | isangel
# Processing Record 24 of Set 6 | karawang
# Processing Record 25 of Set 6 | chitral
# Processing Record 26 of Set 6 | sorland
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | lazaro cardenas
# Processing Record 29 of Set 6 | bilibino
# Processing Record 30 of Set 6 | lorengau
# Processing Record 31 of Set 6 | krasnoselkup
# Processing Record 32 of Set 6 | potanino
# Processing Record 33 of Set 6 | kamina
# Processing Record 34 of Set 6 | kavaratti
# Processing Record 35 of Set 6 | sirjan
# Processing Record 36 of Set 6 | sidney
# Processing Record 37 of Set 6 | racine
# Processing Record 38 of Set 6 | nishihara
# Processing Record 39 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 40 of Set 6 | bandiagara
# Processing Record 41 of Set 6 | port hedland
# Processing Record 42 of Set 6 | sao lourenco do sul
# Processing Record 43 of Set 6 | broken hill
# Processing Record 44 of Set 6 | havre
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | pahrump
# Processing Record 47 of Set 6 | lavrentiya
# Processing Record 48 of Set 6 | lithakia
# Processing Record 49 of Set 6 | agaro
# Processing Record 50 of Set 6 | flinders
# Processing Record 1 of Set 7 | tabory
# Processing Record 2 of Set 7 | copala
# Processing Record 3 of Set 7 | sampit
# Processing Record 4 of Set 7 | nelson bay
# Processing Record 5 of Set 7 | santiago del estero
# Processing Record 6 of Set 7 | pemangkat
# Processing Record 7 of Set 7 | lasa
# Processing Record 8 of Set 7 | khon kaen
# Processing Record 9 of Set 7 | garowe
# Processing Record 10 of Set 7 | birao
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | muli
# Processing Record 14 of Set 7 | mehamn
# Processing Record 15 of Set 7 | corning
# Processing Record 16 of Set 7 | hofn
# Processing Record 17 of Set 7 | andenes
# Processing Record 18 of Set 7 | mana
# Processing Record 19 of Set 7 | kodiak
# Processing Record 20 of Set 7 | eureka
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | ambilobe
# Processing Record 23 of Set 7 | altay
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | mahibadhoo
# Processing Record 26 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 7 | lipari
# Processing Record 28 of Set 7 | giyon
# Processing Record 29 of Set 7 | samfya
# Processing Record 30 of Set 7 | tutoia
# Processing Record 31 of Set 7 | ishinomaki
# Processing Record 32 of Set 7 | conceicao do araguaia
# Processing Record 33 of Set 7 | raudeberg
# Processing Record 34 of Set 7 | atamanovka
# Processing Record 35 of Set 7 | bandarbeyla
# Processing Record 36 of Set 7 | tsarychanka
# Processing Record 37 of Set 7 | shyryayeve
# Processing Record 38 of Set 7 | big spring
# Processing Record 39 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | olga
# Processing Record 41 of Set 7 | amboasary
# Processing Record 42 of Set 7 | waddan
# Processing Record 43 of Set 7 | barreiras
# Processing Record 44 of Set 7 | ulaangom
# Processing Record 45 of Set 7 | dingle
# Processing Record 46 of Set 7 | bubaque
# Processing Record 47 of Set 7 | katsuura
# Processing Record 48 of Set 7 | griffith
# Processing Record 49 of Set 7 | broome
# Processing Record 50 of Set 7 | kaeo
# Processing Record 1 of Set 8 | oeiras do para
# Processing Record 2 of Set 8 | maniitsoq
# Processing Record 3 of Set 8 | lakatoro
# Processing Record 4 of Set 8 | margate
# Processing Record 5 of Set 8 | port-cartier
# Processing Record 6 of Set 8 | elizabeth city
# Processing Record 7 of Set 8 | shache
# Processing Record 8 of Set 8 | thompson
# Processing Record 9 of Set 8 | marystown
# Processing Record 10 of Set 8 | ostrovnoy
# Processing Record 11 of Set 8 | adrar
# Processing Record 12 of Set 8 | baijiantan
# Processing Record 13 of Set 8 | akdepe
# Processing Record 14 of Set 8 | catamarca
# Processing Record 15 of Set 8 | alta
# Processing Record 16 of Set 8 | geraldton
# Processing Record 17 of Set 8 | sterling
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | huarmey
# Processing Record 20 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 8 | orebro
# Processing Record 22 of Set 8 | benguela
# Processing Record 23 of Set 8 | castro
# Processing Record 24 of Set 8 | ivanava
# Processing Record 25 of Set 8 | bima
# Processing Record 26 of Set 8 | lokosovo
# Processing Record 27 of Set 8 | aromashevo
# Processing Record 28 of Set 8 | beisfjord
# Processing Record 29 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 8 | rudiskes
# Processing Record 31 of Set 8 | ketchikan
# Processing Record 32 of Set 8 | lakes entrance
# Processing Record 33 of Set 8 | sol-iletsk
# Processing Record 34 of Set 8 | meadow lake
# Processing Record 35 of Set 8 | temple
# Processing Record 36 of Set 8 | jalu
# Processing Record 37 of Set 8 | wamba
# Processing Record 38 of Set 8 | san carlos
# Processing Record 39 of Set 8 | calvinia
# Processing Record 40 of Set 8 | coahuayana
# Processing Record 41 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 43 of Set 8 | genhe
# Processing Record 44 of Set 8 | bowen
# Processing Record 45 of Set 8 | dhidhdhoo
# Processing Record 46 of Set 8 | sabang
# Processing Record 47 of Set 8 | banjar
# Processing Record 48 of Set 8 | amarante do maranhao
# Processing Record 49 of Set 8 | guaymas
# Processing Record 50 of Set 8 | blagoyevo
# Processing Record 1 of Set 9 | kolosovka
# Processing Record 2 of Set 9 | chicama
# Processing Record 3 of Set 9 | velykyy burluk
# Processing Record 4 of Set 9 | olinda
# Processing Record 5 of Set 9 | nouadhibou
# Processing Record 6 of Set 9 | imeni morozova
# Processing Record 7 of Set 9 | barra patuca
# Processing Record 8 of Set 9 | oranjemund
# Processing Record 9 of Set 9 | fairbanks
# Processing Record 10 of Set 9 | laguna
# Processing Record 11 of Set 9 | qinzhou
# Processing Record 12 of Set 9 | ishigaki
# Processing Record 13 of Set 9 | novikovo
# Processing Record 14 of Set 9 | ornskoldsvik
# Processing Record 15 of Set 9 | kokopo
# Processing Record 16 of Set 9 | asau
# Processing Record 17 of Set 9 | roma
# Processing Record 18 of Set 9 | maceio
# Processing Record 19 of Set 9 | mount gambier
# Processing Record 20 of Set 9 | sao filipe
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | high level
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | pangkalanbuun
# Processing Record 25 of Set 9 | westport
# Processing Record 26 of Set 9 | gull lake
# Processing Record 27 of Set 9 | caiaponia
# Processing Record 28 of Set 9 | yelatma
# Processing Record 29 of Set 9 | yeppoon
# Processing Record 30 of Set 9 | zacualpan
# Processing Record 31 of Set 9 | boyolangu
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | sept-iles
# Processing Record 34 of Set 9 | mastic beach
# Processing Record 35 of Set 9 | kamenka
# Processing Record 36 of Set 9 | anantapur
# Processing Record 37 of Set 9 | husavik
# Processing Record 38 of Set 9 | yamada
# Processing Record 39 of Set 9 | guerrero negro
# Processing Record 40 of Set 9 | grand-santi
# Processing Record 41 of Set 9 | gao
# Processing Record 42 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 43 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 9 | umuahia
# Processing Record 45 of Set 9 | boyle
# Processing Record 46 of Set 9 | omsukchan
# Processing Record 47 of Set 9 | tankhoy
# Processing Record 48 of Set 9 | banswada
# Processing Record 49 of Set 9 | shar
# Processing Record 50 of Set 9 | bykovo
# Processing Record 1 of Set 10 | wanning
# Processing Record 2 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 10 | srednekolymsk
# Processing Record 4 of Set 10 | carutapera
# Processing Record 5 of Set 10 | chudovo
# Processing Record 6 of Set 10 | pasni
# Processing Record 7 of Set 10 | kampot
# Processing Record 8 of Set 10 | kashi
# Processing Record 9 of Set 10 | ben tre
# Processing Record 10 of Set 10 | munkebo
# Processing Record 11 of Set 10 | sredniy ikorets
# Processing Record 12 of Set 10 | darhan
# Processing Record 13 of Set 10 | shirokiy
# Processing Record 14 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 10 | villazon
# Processing Record 16 of Set 10 | kerman
# Processing Record 17 of Set 10 | dolgoye
# Processing Record 18 of Set 10 | deputatskiy
# Processing Record 19 of Set 10 | patnagarh
# Processing Record 20 of Set 10 | santa cruz
# Processing Record 21 of Set 10 | ahipara
# Processing Record 22 of Set 10 | pisco
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | ligayan
# Processing Record 25 of Set 10 | mitu
# Processing Record 26 of Set 10 | tsaratanana
# Processing Record 27 of Set 10 | kilindoni
# Processing Record 28 of Set 10 | mount isa
# Processing Record 29 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 10 | ugoofaaru
# Processing Record 31 of Set 10 | honiara
# Processing Record 32 of Set 10 | rodrigues alves
# Processing Record 33 of Set 10 | kashan
# Processing Record 34 of Set 10 | viedma
# Processing Record 35 of Set 10 | ulsteinvik
# Processing Record 36 of Set 10 | mangrol
# Processing Record 37 of Set 10 | fereydun kenar
# Processing Record 38 of Set 10 | ovre ardal
# Processing Record 39 of Set 10 | palana
# Processing Record 40 of Set 10 | lufilufi
# Processing Record 41 of Set 10 | sarkand
# Processing Record 42 of Set 10 | balad
# Processing Record 43 of Set 10 | ivajlovgrad
# City not found. Skipping...
# Processing Record 44 of Set 10 | dilla
# Processing Record 45 of Set 10 | sisimiut
# Processing Record 46 of Set 10 | norman wells
# Processing Record 47 of Set 10 | murray bridge
# Processing Record 48 of Set 10 | ulladulla
# Processing Record 49 of Set 10 | christchurch
# Processing Record 50 of Set 10 | waterloo
# Processing Record 1 of Set 11 | atar
# Processing Record 2 of Set 11 | kahului
# Processing Record 3 of Set 11 | at-bashi
# Processing Record 4 of Set 11 | billings
# Processing Record 5 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 11 | brownsville
# Processing Record 7 of Set 11 | arman
# Processing Record 8 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 11 | zhigansk
# Processing Record 10 of Set 11 | tanout
# Processing Record 11 of Set 11 | tumarbong
# Processing Record 12 of Set 11 | myanaung
# Processing Record 13 of Set 11 | iskateley
# Processing Record 14 of Set 11 | durazno
# Processing Record 15 of Set 11 | bereda
# Processing Record 16 of Set 11 | ekhabi
# Processing Record 17 of Set 11 | leon
# Processing Record 18 of Set 11 | bud
# Processing Record 19 of Set 11 | salvador
# Processing Record 20 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 21 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 22 of Set 11 | skelleftea
# Processing Record 23 of Set 11 | kalat
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | cairns
# Processing Record 26 of Set 11 | xinzhou
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | pimentel
# Processing Record 29 of Set 11 | keflavik
# Processing Record 30 of Set 11 | touros
# Processing Record 31 of Set 11 | chekhov
# Processing Record 32 of Set 11 | henties bay
# Processing Record 33 of Set 11 | jumla
# Processing Record 34 of Set 11 | tharad
# Processing Record 35 of Set 11 | bayanday
# Processing Record 36 of Set 11 | tambun
# Processing Record 37 of Set 11 | benoy
# Processing Record 38 of Set 11 | minot
# Processing Record 39 of Set 11 | narsaq
# Processing Record 40 of Set 11 | chapais
# Processing Record 41 of Set 11 | vila do maio
# Processing Record 42 of Set 11 | baruun-urt
# Processing Record 43 of Set 11 | ilulissat
# Processing Record 44 of Set 11 | patawag
# Processing Record 45 of Set 11 | shihezi
# Processing Record 46 of Set 11 | hearst
# Processing Record 47 of Set 11 | madang
# Processing Record 48 of Set 11 | bukama
# Processing Record 49 of Set 11 | nador
# Processing Record 50 of Set 11 | ulaanbaatar
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 3 of Set 12 | riyadh
# Processing Record 4 of Set 12 | quelimane
# Processing Record 5 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 12 | leeton
# Processing Record 7 of Set 12 | freilassing
# Processing Record 8 of Set 12 | fukue
# Processing Record 9 of Set 12 | ponta delgada
# Processing Record 10 of Set 12 | port lincoln
# Processing Record 11 of Set 12 | brandon
# Processing Record 12 of Set 12 | kawalu
# Processing Record 13 of Set 12 | coromandel
# Processing Record 14 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 12 | tucurui
# Processing Record 16 of Set 12 | paramonga
# Processing Record 17 of Set 12 | ous
# Processing Record 18 of Set 12 | sao joao da barra
# Processing Record 19 of Set 12 | vilyuysk
# Processing Record 20 of Set 12 | lumphat
# Processing Record 21 of Set 12 | sanchor
# Processing Record 22 of Set 12 | roald
# Processing Record 23 of Set 12 | biharamulo
# Processing Record 24 of Set 12 | palafrugell
# Processing Record 25 of Set 12 | koungou
# Processing Record 26 of Set 12 | bayan
# Processing Record 27 of Set 12 | pozo colorado
# Processing Record 28 of Set 12 | bilma
# Processing Record 29 of Set 12 | ust-tsilma
# Processing Record 30 of Set 12 | kemijarvi
# Processing Record 31 of Set 12 | sinnamary
# Processing Record 32 of Set 12 | kibara
# Processing Record 33 of Set 12 | san andres
# Processing Record 34 of Set 12 | san policarpo
# Processing Record 35 of Set 12 | cabedelo
# Processing Record 36 of Set 12 | san juan bautista
# Processing Record 37 of Set 12 | mitsamiouli
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | mezen
# Processing Record 40 of Set 12 | nanakuli
# Processing Record 41 of Set 12 | gornopravdinsk
# Processing Record 42 of Set 12 | whakatane
# Processing Record 43 of Set 12 | kirakira
# Processing Record 44 of Set 12 | itupiranga
# Processing Record 45 of Set 12 | palu
# Processing Record 46 of Set 12 | the valley
# Processing Record 47 of Set 12 | douglas
# Processing Record 48 of Set 12 | bolobo
# Processing Record 49 of Set 12 | durban
# Processing Record 50 of Set 12 | zhoucun
# Processing Record 1 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 13 | sayyan
# Processing Record 3 of Set 13 | malkangiri
# Processing Record 4 of Set 13 | zarinsk
# Processing Record 5 of Set 13 | hastings
# Processing Record 6 of Set 13 | san patricio
# Processing Record 7 of Set 13 | talcahuano
# Processing Record 8 of Set 13 | dwarka
# Processing Record 9 of Set 13 | san vicente
# Processing Record 10 of Set 13 | ferme-neuve
# Processing Record 11 of Set 13 | san carlos de bariloche
# Processing Record 12 of Set 13 | zomin
# Processing Record 13 of Set 13 | barentu
# Processing Record 14 of Set 13 | kungurtug
# Processing Record 15 of Set 13 | olymskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | shimoda
# Processing Record 17 of Set 13 | kinablangan
# Processing Record 18 of Set 13 | abu samrah
# Processing Record 19 of Set 13 | meulaboh
# Processing Record 20 of Set 13 | worthington
# Processing Record 21 of Set 13 | nacala
# Processing Record 22 of Set 13 | ambon
# Processing Record 23 of Set 13 | natal
# Processing Record 24 of Set 13 | kosh-agach
# Processing Record 25 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 26 of Set 13 | sabha
# Processing Record 27 of Set 13 | inuvik
# Processing Record 28 of Set 13 | iquique
# Processing Record 29 of Set 13 | markova
# Processing Record 30 of Set 13 | nombre de dios
# Processing Record 31 of Set 13 | barranca
# Processing Record 32 of Set 13 | nuevo progreso
# Processing Record 33 of Set 13 | teguldet
# Processing Record 34 of Set 13 | rioja
# Processing Record 35 of Set 13 | atocha
# Processing Record 36 of Set 13 | galle
# Processing Record 37 of Set 13 | naron
# Processing Record 38 of Set 13 | mnogovershinnyy
# Processing Record 39 of Set 13 | thinadhoo
# Processing Record 40 of Set 13 | itacare
# Processing Record 41 of Set 13 | labrea
# Processing Record 42 of Set 13 | kirkwood
# Processing Record 43 of Set 13 | wajima
# Processing Record 44 of Set 13 | bonthe
# Processing Record 45 of Set 13 | maragogipe
# Processing Record 46 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 13 | tiarei
# Processing Record 48 of Set 13 | astoria
# Processing Record 49 of Set 13 | uspenka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities

number_cities = len(city_data)
number_cities
# Out:
# 602

# %%
# Convert the array of dictionaries to a Pandas Dataframe

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Shieli  44.1667   66.7500     75.76        27           9
# 1  Joao Pinheiro -17.7425  -46.1725     76.84        29          60
# 2      Jamestown  42.0970  -79.2353     76.51        88           0
# 3          Bluff -46.6000  168.3333     43.81        81          94
# 4      Busselton -33.6500  115.3333     46.96        85          21
#
#    Wind Speed Country                 Date
# 0        7.54      KZ  2022-08-29 22:09:25
# 1        6.91      BR  2022-08-29 22:09:26
# 2       12.66      US  2022-08-29 22:04:41
# 3        6.38      NZ  2022-08-29 22:09:26
# 4        6.40      AU  2022-08-29 22:09:26

# %%
# Reorder the columns

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0         Shieli      KZ  2022-08-29 22:09:25  44.1667   66.7500     75.76
# 1  Joao Pinheiro      BR  2022-08-29 22:09:26 -17.7425  -46.1725     76.84
# 2      Jamestown      US  2022-08-29 22:04:41  42.0970  -79.2353     76.51
# 3          Bluff      NZ  2022-08-29 22:09:26 -46.6000  168.3333     43.81
# 4      Busselton      AU  2022-08-29 22:09:26 -33.6500  115.3333     46.96
#
#    Humidity  Cloudiness  Wind Speed
# 0        27           9        7.54
# 1        29          60        6.91
# 2        88           0       12.66
# 3        81          94        6.38
# 4        85          21        6.40

# %%
# Create the output file(CSV)

output_data_file = "weather_data/cities.csv"

# Export the City_Data in a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today = time.strftime("%x")
today
# Out:
# '08/29/22'

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig1.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig3.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig4.png")

#Show plot
plt.show()
