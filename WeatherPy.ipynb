# %%
# Import the dependencies

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
# Import the requests library
import requests

# import the API key
from config import weather_api_key

# %%
# Starting URl for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9238727c7158ceca2ba4693bf673118a

# %%
# Import the time linrary

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging

print("Beginning data retrieval     ")
print("-----------------------------")


# Create counters

record_count = 1
set_count = 1
# Out:
# Beginning data retrieval
# -----------------------------

# %%
# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
       # time.sleep(60)
        
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    # Log the URL, record, and et numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    
    record_count += 1
    
# Run an API request for each of the cities

    try:
        # parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
                # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | jalu
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | mareeba
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | noumea
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | sergeyevka
# Processing Record 18 of Set 1 | ahipara
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | poum
# Processing Record 21 of Set 1 | bograd
# Processing Record 22 of Set 1 | cerritos
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | lavrentiya
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | birao
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | nishihara
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | ballina
# Processing Record 36 of Set 1 | reyes
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | mayskiy
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | hot springs
# Processing Record 46 of Set 1 | shingu
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | salekhard
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | banjar
# Processing Record 2 of Set 2 | avera
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | atasu
# Processing Record 5 of Set 2 | cherskiy
# Processing Record 6 of Set 2 | henties bay
# Processing Record 7 of Set 2 | constitucion
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | chicama
# Processing Record 15 of Set 2 | zyryanka
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | kawalu
# Processing Record 18 of Set 2 | aklavik
# Processing Record 19 of Set 2 | bhadrachalam
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | mikuni
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | praia da vitoria
# Processing Record 24 of Set 2 | camacha
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | fethiye
# Processing Record 32 of Set 2 | cowra
# Processing Record 33 of Set 2 | bongaree
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | yining
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | houston
# Processing Record 39 of Set 2 | japura
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | esperantinopolis
# Processing Record 42 of Set 2 | amnat charoen
# Processing Record 43 of Set 2 | wiarton
# Processing Record 44 of Set 2 | kouqian
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | fairbanks
# Processing Record 47 of Set 2 | hami
# Processing Record 48 of Set 2 | libourne
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | santarem
# Processing Record 1 of Set 3 | mao
# Processing Record 2 of Set 3 | chirongui
# Processing Record 3 of Set 3 | najran
# Processing Record 4 of Set 3 | hervey bay
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | kushima
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | north bend
# Processing Record 9 of Set 3 | churapcha
# Processing Record 10 of Set 3 | porto nacional
# Processing Record 11 of Set 3 | terrak
# Processing Record 12 of Set 3 | haikou
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | pacific grove
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | tyup
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | katherine
# Processing Record 19 of Set 3 | agdam
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | beira
# Processing Record 24 of Set 3 | waipawa
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | saint anthony
# Processing Record 27 of Set 3 | buala
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | tabou
# Processing Record 31 of Set 3 | tutoia
# Processing Record 32 of Set 3 | nakamura
# Processing Record 33 of Set 3 | bosaso
# Processing Record 34 of Set 3 | turbat
# Processing Record 35 of Set 3 | nobres
# Processing Record 36 of Set 3 | ekhabi
# Processing Record 37 of Set 3 | arkhangelsk
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | springfield
# Processing Record 41 of Set 3 | solnechnyy
# Processing Record 42 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 3 | zhucheng
# Processing Record 44 of Set 3 | punta arenas
# Processing Record 45 of Set 3 | bokoro
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | sarangani
# Processing Record 49 of Set 3 | santa maria
# Processing Record 50 of Set 3 | mae chan
# Processing Record 1 of Set 4 | saldanha
# Processing Record 2 of Set 4 | tautira
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | turukhansk
# Processing Record 6 of Set 4 | soyo
# Processing Record 7 of Set 4 | asau
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | brae
# Processing Record 10 of Set 4 | albion
# Processing Record 11 of Set 4 | mecca
# Processing Record 12 of Set 4 | kirakira
# Processing Record 13 of Set 4 | varazze
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | alta floresta
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | husavik
# Processing Record 18 of Set 4 | quimper
# Processing Record 19 of Set 4 | cockburn town
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | ukiah
# Processing Record 22 of Set 4 | vanimo
# Processing Record 23 of Set 4 | monterey
# Processing Record 24 of Set 4 | dingle
# Processing Record 25 of Set 4 | singapore
# Processing Record 26 of Set 4 | aswan
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | wawa
# Processing Record 29 of Set 4 | isangel
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | bibiani
# Processing Record 32 of Set 4 | atambua
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 4 | wenling
# Processing Record 38 of Set 4 | domoni
# Processing Record 39 of Set 4 | maceio
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | ayagoz
# Processing Record 42 of Set 4 | hilo
# Processing Record 43 of Set 4 | ulu-telyak
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | mount isa
# Processing Record 46 of Set 4 | mahajanga
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | muriti
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 50 of Set 4 | katsuura
# Processing Record 1 of Set 5 | eyl
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | anadyr
# Processing Record 4 of Set 5 | mar del plata
# Processing Record 5 of Set 5 | nicoya
# Processing Record 6 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | saint-louis
# Processing Record 10 of Set 5 | tessalit
# Processing Record 11 of Set 5 | nyurba
# Processing Record 12 of Set 5 | boulogne-sur-mer
# Processing Record 13 of Set 5 | maldonado
# Processing Record 14 of Set 5 | okato
# Processing Record 15 of Set 5 | kaeo
# Processing Record 16 of Set 5 | maridi
# Processing Record 17 of Set 5 | eldorado
# Processing Record 18 of Set 5 | matara
# Processing Record 19 of Set 5 | belaya gora
# Processing Record 20 of Set 5 | hamadan
# Processing Record 21 of Set 5 | sao filipe
# Processing Record 22 of Set 5 | abu samrah
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | saint-georges
# Processing Record 25 of Set 5 | valparaiso
# Processing Record 26 of Set 5 | wilmington island
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | sola
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | kamenka
# Processing Record 33 of Set 5 | sassandra
# Processing Record 34 of Set 5 | bonfim
# Processing Record 35 of Set 5 | flinders
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 38 of Set 5 | saiha
# Processing Record 39 of Set 5 | yerbogachen
# Processing Record 40 of Set 5 | omsukchan
# Processing Record 41 of Set 5 | macau
# Processing Record 42 of Set 5 | uruguaiana
# Processing Record 43 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 5 | melilla
# Processing Record 45 of Set 5 | wanaka
# Processing Record 46 of Set 5 | mahebourg
# Processing Record 47 of Set 5 | slave lake
# Processing Record 48 of Set 5 | qandala
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | burica
# City not found. Skipping...
# Processing Record 1 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 6 | oriximina
# Processing Record 3 of Set 6 | yakeshi
# Processing Record 4 of Set 6 | nacimiento
# Processing Record 5 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | novaya ladoga
# Processing Record 7 of Set 6 | maragogi
# Processing Record 8 of Set 6 | cayenne
# Processing Record 9 of Set 6 | impfondo
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | salta
# Processing Record 12 of Set 6 | touros
# Processing Record 13 of Set 6 | pirmasens
# Processing Record 14 of Set 6 | buin
# Processing Record 15 of Set 6 | sao felix do xingu
# Processing Record 16 of Set 6 | hualmay
# Processing Record 17 of Set 6 | semnan
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | tateyama
# Processing Record 20 of Set 6 | amahai
# Processing Record 21 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 6 | shakhtinsk
# Processing Record 23 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 6 | balabac
# Processing Record 25 of Set 6 | qaanaaq
# Processing Record 26 of Set 6 | arrah
# Processing Record 27 of Set 6 | arlit
# Processing Record 28 of Set 6 | kenai
# Processing Record 29 of Set 6 | ambovombe
# Processing Record 30 of Set 6 | chapais
# Processing Record 31 of Set 6 | coquimbo
# Processing Record 32 of Set 6 | blagodarnyy
# Processing Record 33 of Set 6 | la ronge
# Processing Record 34 of Set 6 | fare
# Processing Record 35 of Set 6 | belyy yar
# Processing Record 36 of Set 6 | santa cruz
# Processing Record 37 of Set 6 | nuzvid
# Processing Record 38 of Set 6 | rocha
# Processing Record 39 of Set 6 | road town
# Processing Record 40 of Set 6 | alofi
# Processing Record 41 of Set 6 | karratha
# Processing Record 42 of Set 6 | marapanim
# Processing Record 43 of Set 6 | quatre cocos
# Processing Record 44 of Set 6 | goderich
# Processing Record 45 of Set 6 | westport
# Processing Record 46 of Set 6 | anito
# Processing Record 47 of Set 6 | santa fe
# Processing Record 48 of Set 6 | caravelas
# Processing Record 49 of Set 6 | wagar
# Processing Record 50 of Set 6 | bandarbeyla
# Processing Record 1 of Set 7 | karachi
# Processing Record 2 of Set 7 | awash
# Processing Record 3 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 7 | hazebrouck
# Processing Record 5 of Set 7 | temple
# Processing Record 6 of Set 7 | bonavista
# Processing Record 7 of Set 7 | trinidad
# Processing Record 8 of Set 7 | xiantao
# Processing Record 9 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | sobolevo
# Processing Record 11 of Set 7 | buraydah
# Processing Record 12 of Set 7 | sibu
# Processing Record 13 of Set 7 | saint-ambroise
# Processing Record 14 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 15 of Set 7 | umm lajj
# Processing Record 16 of Set 7 | nampula
# Processing Record 17 of Set 7 | cardston
# Processing Record 18 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 7 | puerto leguizamo
# Processing Record 22 of Set 7 | san fernando
# Processing Record 23 of Set 7 | thinadhoo
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | aginskoye
# Processing Record 26 of Set 7 | sabalgarh
# Processing Record 27 of Set 7 | kastamonu
# Processing Record 28 of Set 7 | dukat
# Processing Record 29 of Set 7 | auki
# Processing Record 30 of Set 7 | adrar
# Processing Record 31 of Set 7 | helmstedt
# Processing Record 32 of Set 7 | lebedyn
# Processing Record 33 of Set 7 | svetlaya
# Processing Record 34 of Set 7 | great yarmouth
# Processing Record 35 of Set 7 | olutanga
# Processing Record 36 of Set 7 | bamnet narong
# Processing Record 37 of Set 7 | mandalgovi
# Processing Record 38 of Set 7 | vestmannaeyjar
# Processing Record 39 of Set 7 | yaviza
# Processing Record 40 of Set 7 | mazara del vallo
# Processing Record 41 of Set 7 | sabang
# Processing Record 42 of Set 7 | saskylakh
# Processing Record 43 of Set 7 | anloga
# Processing Record 44 of Set 7 | nanakuli
# Processing Record 45 of Set 7 | poso
# Processing Record 46 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | canora
# Processing Record 49 of Set 7 | vardo
# Processing Record 50 of Set 7 | ixtapa
# Processing Record 1 of Set 8 | carnarvon
# Processing Record 2 of Set 8 | igra
# Processing Record 3 of Set 8 | krasnyy chikoy
# Processing Record 4 of Set 8 | pathein
# Processing Record 5 of Set 8 | benguela
# Processing Record 6 of Set 8 | rorvik
# Processing Record 7 of Set 8 | talavera de la reina
# Processing Record 8 of Set 8 | san jose
# Processing Record 9 of Set 8 | eureka
# Processing Record 10 of Set 8 | santa isabel do rio negro
# Processing Record 11 of Set 8 | te anau
# Processing Record 12 of Set 8 | bougouni
# Processing Record 13 of Set 8 | san patricio
# Processing Record 14 of Set 8 | norilsk
# Processing Record 15 of Set 8 | san quintin
# Processing Record 16 of Set 8 | kwinana
# Processing Record 17 of Set 8 | marrakesh
# Processing Record 18 of Set 8 | aleksandrov gay
# Processing Record 19 of Set 8 | seoul
# Processing Record 20 of Set 8 | jawhar
# Processing Record 21 of Set 8 | ostrovnoy
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | kruisfontein
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | boyuibe
# Processing Record 26 of Set 8 | ayan
# Processing Record 27 of Set 8 | ginir
# Processing Record 28 of Set 8 | tanout
# Processing Record 29 of Set 8 | dunedin
# Processing Record 30 of Set 8 | turayf
# Processing Record 31 of Set 8 | tukums
# Processing Record 32 of Set 8 | carballo
# Processing Record 33 of Set 8 | salalah
# Processing Record 34 of Set 8 | sao jose do campestre
# Processing Record 35 of Set 8 | gondar
# Processing Record 36 of Set 8 | esil
# Processing Record 37 of Set 8 | havre-saint-pierre
# Processing Record 38 of Set 8 | puerto escondido
# Processing Record 39 of Set 8 | majene
# Processing Record 40 of Set 8 | dawei
# Processing Record 41 of Set 8 | saint george
# Processing Record 42 of Set 8 | wonthaggi
# Processing Record 43 of Set 8 | ashta
# Processing Record 44 of Set 8 | comodoro rivadavia
# Processing Record 45 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 8 | roald
# Processing Record 47 of Set 8 | schitu
# Processing Record 48 of Set 8 | nuevitas
# Processing Record 49 of Set 8 | aksha
# Processing Record 50 of Set 8 | nome
# Processing Record 1 of Set 9 | bam
# Processing Record 2 of Set 9 | igrim
# Processing Record 3 of Set 9 | kiunga
# Processing Record 4 of Set 9 | lunino
# Processing Record 5 of Set 9 | marzuq
# Processing Record 6 of Set 9 | shitanjing
# Processing Record 7 of Set 9 | shenjiamen
# Processing Record 8 of Set 9 | filingue
# Processing Record 9 of Set 9 | mahendragarh
# Processing Record 10 of Set 9 | lubao
# Processing Record 11 of Set 9 | eirunepe
# Processing Record 12 of Set 9 | bousso
# Processing Record 13 of Set 9 | daru
# Processing Record 14 of Set 9 | espanola
# Processing Record 15 of Set 9 | les cayes
# Processing Record 16 of Set 9 | awjilah
# Processing Record 17 of Set 9 | usevya
# Processing Record 18 of Set 9 | robe
# Processing Record 19 of Set 9 | oranjestad
# Processing Record 20 of Set 9 | linjiang
# Processing Record 21 of Set 9 | san cristobal
# Processing Record 22 of Set 9 | port elizabeth
# Processing Record 23 of Set 9 | gizo
# Processing Record 24 of Set 9 | benghazi
# Processing Record 25 of Set 9 | zelenogradsk
# Processing Record 26 of Set 9 | temyasovo
# Processing Record 27 of Set 9 | olafsvik
# Processing Record 28 of Set 9 | natchez
# Processing Record 29 of Set 9 | marystown
# Processing Record 30 of Set 9 | xining
# Processing Record 31 of Set 9 | chimoio
# Processing Record 32 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 9 | dubbo
# Processing Record 34 of Set 9 | pangody
# Processing Record 35 of Set 9 | acajutla
# Processing Record 36 of Set 9 | beyneu
# Processing Record 37 of Set 9 | madang
# Processing Record 38 of Set 9 | zhigansk
# Processing Record 39 of Set 9 | bria
# Processing Record 40 of Set 9 | bubaque
# Processing Record 41 of Set 9 | ventersburg
# Processing Record 42 of Set 9 | talnakh
# Processing Record 43 of Set 9 | ashland
# Processing Record 44 of Set 9 | hermiston
# Processing Record 45 of Set 9 | gat
# Processing Record 46 of Set 9 | richards bay
# Processing Record 47 of Set 9 | makung
# City not found. Skipping...
# Processing Record 48 of Set 9 | kyenjojo
# Processing Record 49 of Set 9 | itarema
# Processing Record 50 of Set 9 | manokwari
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | sladkovo
# Processing Record 3 of Set 10 | shimoda
# Processing Record 4 of Set 10 | wanning
# Processing Record 5 of Set 10 | nouadhibou
# Processing Record 6 of Set 10 | andenes
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | carutapera
# Processing Record 9 of Set 10 | giyani
# Processing Record 10 of Set 10 | baker city
# Processing Record 11 of Set 10 | carson city
# Processing Record 12 of Set 10 | bonthe
# Processing Record 13 of Set 10 | kushiro
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | wajima
# Processing Record 16 of Set 10 | almaznyy
# Processing Record 17 of Set 10 | salmas
# Processing Record 18 of Set 10 | lukulu
# Processing Record 19 of Set 10 | saqqez
# Processing Record 20 of Set 10 | labuhan
# Processing Record 21 of Set 10 | fairfield
# Processing Record 22 of Set 10 | karabuk
# Processing Record 23 of Set 10 | nanortalik
# Processing Record 24 of Set 10 | rognan
# Processing Record 25 of Set 10 | codrington
# Processing Record 26 of Set 10 | ormara
# Processing Record 27 of Set 10 | isnos
# Processing Record 28 of Set 10 | san juan
# Processing Record 29 of Set 10 | mosquera
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | amarillo
# Processing Record 32 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 10 | rehoboth
# Processing Record 34 of Set 10 | bardiyah
# Processing Record 35 of Set 10 | mungwi
# Processing Record 36 of Set 10 | mogwase
# Processing Record 37 of Set 10 | vila
# Processing Record 38 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 10 | maningrida
# Processing Record 40 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 10 | monroe
# Processing Record 42 of Set 10 | pitimbu
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | dumai
# Processing Record 45 of Set 10 | olonets
# Processing Record 46 of Set 10 | koslan
# Processing Record 47 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 10 | kracheh
# City not found. Skipping...
# Processing Record 49 of Set 10 | kupang
# Processing Record 50 of Set 10 | pedernales
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | las rosas
# Processing Record 3 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 4 of Set 11 | tallahassee
# Processing Record 5 of Set 11 | hofn
# Processing Record 6 of Set 11 | imbituba
# Processing Record 7 of Set 11 | alyangula
# Processing Record 8 of Set 11 | mezen
# Processing Record 9 of Set 11 | ridgecrest
# Processing Record 10 of Set 11 | le raincy
# Processing Record 11 of Set 11 | tonantins
# Processing Record 12 of Set 11 | agadir
# Processing Record 13 of Set 11 | olinda
# Processing Record 14 of Set 11 | tarabuco
# Processing Record 15 of Set 11 | port macquarie
# Processing Record 16 of Set 11 | college
# Processing Record 17 of Set 11 | beaverlodge
# Processing Record 18 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 19 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | bilma
# Processing Record 21 of Set 11 | knysna
# Processing Record 22 of Set 11 | omboue
# Processing Record 23 of Set 11 | kloulklubed
# Processing Record 24 of Set 11 | lahaina
# Processing Record 25 of Set 11 | marsa matruh
# Processing Record 26 of Set 11 | rawah
# Processing Record 27 of Set 11 | sept-iles
# Processing Record 28 of Set 11 | pelym
# Processing Record 29 of Set 11 | sfantu gheorghe
# Processing Record 30 of Set 11 | yeppoon
# Processing Record 31 of Set 11 | ubon ratchathani
# Processing Record 32 of Set 11 | rena
# Processing Record 33 of Set 11 | tucuman
# Processing Record 34 of Set 11 | wadi maliz
# Processing Record 35 of Set 11 | puro
# Processing Record 36 of Set 11 | makakilo city
# Processing Record 37 of Set 11 | chitral
# Processing Record 38 of Set 11 | fort nelson
# Processing Record 39 of Set 11 | palaikastron
# Processing Record 40 of Set 11 | huilong
# Processing Record 41 of Set 11 | mezhdurechensk
# Processing Record 42 of Set 11 | koutsouras
# Processing Record 43 of Set 11 | dunkirk
# Processing Record 44 of Set 11 | chuy
# Processing Record 45 of Set 11 | mabaruma
# Processing Record 46 of Set 11 | nioro
# Processing Record 47 of Set 11 | gannan
# Processing Record 48 of Set 11 | kerchevskiy
# Processing Record 49 of Set 11 | biak
# Processing Record 50 of Set 11 | morlaix
# Processing Record 1 of Set 12 | nizhnevartovsk
# Processing Record 2 of Set 12 | ulaangom
# Processing Record 3 of Set 12 | aykhal
# Processing Record 4 of Set 12 | berlevag
# Processing Record 5 of Set 12 | diveyevo
# Processing Record 6 of Set 12 | keti bandar
# Processing Record 7 of Set 12 | byron bay
# Processing Record 8 of Set 12 | gajendragarh
# Processing Record 9 of Set 12 | zapadnaya dvina
# Processing Record 10 of Set 12 | nemuro
# Processing Record 11 of Set 12 | kashi
# Processing Record 12 of Set 12 | thunder bay
# Processing Record 13 of Set 12 | gigmoto
# Processing Record 14 of Set 12 | tshikapa
# Processing Record 15 of Set 12 | deer lake
# Processing Record 16 of Set 12 | novyy urengoy
# Processing Record 17 of Set 12 | akyab
# Processing Record 18 of Set 12 | surgut
# Processing Record 19 of Set 12 | revadanda
# Processing Record 20 of Set 12 | galdar
# Processing Record 21 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 12 | mount gambier
# Processing Record 23 of Set 12 | fernie
# Processing Record 24 of Set 12 | kolondieba
# Processing Record 25 of Set 12 | zeya
# Processing Record 26 of Set 12 | altamira
# Processing Record 27 of Set 12 | salym
# Processing Record 28 of Set 12 | cambridge
# Processing Record 29 of Set 12 | atar
# Processing Record 30 of Set 12 | anchorage
# Processing Record 31 of Set 12 | alekseyevsk
# Processing Record 32 of Set 12 | kahului
# Processing Record 33 of Set 12 | moosomin
# Processing Record 34 of Set 12 | sambava
# Processing Record 35 of Set 12 | kathmandu
# Processing Record 36 of Set 12 | lompoc
# Processing Record 37 of Set 12 | fernley
# Processing Record 38 of Set 12 | xiongzhou
# Processing Record 39 of Set 12 | sioux falls
# Processing Record 40 of Set 12 | klimovo
# Processing Record 41 of Set 12 | scottsbluff
# Processing Record 42 of Set 12 | ibra
# Processing Record 43 of Set 12 | indramayu
# Processing Record 44 of Set 12 | garowe
# Processing Record 45 of Set 12 | prince rupert
# Processing Record 46 of Set 12 | mananjary
# Processing Record 47 of Set 12 | buena vista
# Processing Record 48 of Set 12 | sarkand
# Processing Record 49 of Set 12 | taoudenni
# Processing Record 50 of Set 12 | druzhba
# Processing Record 1 of Set 13 | pierre
# Processing Record 2 of Set 13 | paamiut
# Processing Record 3 of Set 13 | kysyl-syr
# Processing Record 4 of Set 13 | miri
# Processing Record 5 of Set 13 | jumla
# Processing Record 6 of Set 13 | krasnyy yar
# Processing Record 7 of Set 13 | shirokiy
# Processing Record 8 of Set 13 | nago
# Processing Record 9 of Set 13 | morondava
# Processing Record 10 of Set 13 | catalina
# Processing Record 11 of Set 13 | sibolga
# Processing Record 12 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 13 | san andres
# Processing Record 14 of Set 13 | chadiza
# Processing Record 15 of Set 13 | samarai
# Processing Record 16 of Set 13 | krasnoselkup
# Processing Record 17 of Set 13 | bathsheba
# Processing Record 18 of Set 13 | rypefjord
# Processing Record 19 of Set 13 | mizdah
# Processing Record 20 of Set 13 | korla
# Processing Record 21 of Set 13 | basud
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities

number_cities = len(city_data)
number_cities
# Out:
# 578

# %%
# Convert the array of dictionaries to a Pandas Dataframe

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Jalu  29.0331   21.5482     80.60        42           0
# 1          Albany  42.6001  -73.9662     69.62        91         100
# 2  Saint-Philippe -21.3585   55.7679     71.19        80          73
# 3           Bluff -46.6000  168.3333     62.80        59          78
# 4        Hermanus -34.4187   19.2345     52.81        76           0
#
#    Wind Speed Country                 Date
# 0        6.73      LY  2022-08-31 02:00:48
# 1        8.37      US  2022-08-31 02:00:48
# 2       10.40      RE  2022-08-31 02:00:49
# 3       13.02      NZ  2022-08-31 02:00:49
# 4       23.11      ZA  2022-08-31 02:00:50

# %%
# Reorder the columns

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0            Jalu      LY  2022-08-31 02:00:48  29.0331   21.5482     80.60
# 1          Albany      US  2022-08-31 02:00:48  42.6001  -73.9662     69.62
# 2  Saint-Philippe      RE  2022-08-31 02:00:49 -21.3585   55.7679     71.19
# 3           Bluff      NZ  2022-08-31 02:00:49 -46.6000  168.3333     62.80
# 4        Hermanus      ZA  2022-08-31 02:00:50 -34.4187   19.2345     52.81
#
#    Humidity  Cloudiness  Wind Speed
# 0        42           0        6.73
# 1        91         100        8.37
# 2        80          73       10.40
# 3        59          78       13.02
# 4        76           0       23.11

# %%
# Create the output file(CSV)

output_data_file = "weather_data/cities.csv"

# Export the City_Data in a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today = time.strftime("%x")
today
# Out:
# '08/30/22'

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig1.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig3.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig4.png")

#Show plot
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Call the loc function

index13 = city_data_df.loc[13]
index13
# Out:
# City                   Sergeyevka
# Country                        KZ
# Date          2022-08-31 02:01:04
# Lat                         53.88
# Lng                       67.4158
# Max Temp                    65.77
# Humidity                       56
# Cloudiness                     99
# Wind Speed                   6.26
# Name: 13, dtype: object

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
