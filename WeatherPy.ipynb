# %%
# Import the dependencies

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Import the requests library
import requests

# import the API key
from config import weather_api_key

# %%
# Starting URl for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9238727c7158ceca2ba4693bf673118a

# %%
# Import the time linrary

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging

print("Beginning data retrieval     ")
print("-----------------------------")


# Create counters

record_count = 1
set_count = 1
# Out:
# Beginning data retrieval
# -----------------------------

# %%
# Loop through all the cities in our list

for i, city in enumerate(cities):
    
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    # Log the URL, record, and et numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    
    record_count += 1
    
# Run an API request for each of the cities

    try:
        # parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
                # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | troitsko-pechorsk
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | shimoda
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | galle
# Processing Record 10 of Set 1 | ngunguru
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | jinchang
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | muravlenko
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | mitsamiouli
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | leningradskiy
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | chibombo
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | hualmay
# Processing Record 39 of Set 1 | dingle
# Processing Record 40 of Set 1 | kaoma
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 1 | burica
# City not found. Skipping...
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | concepcion del uruguay
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | college
# Processing Record 1 of Set 2 | jijiang
# Processing Record 2 of Set 2 | marovoay
# Processing Record 3 of Set 2 | flinders
# Processing Record 4 of Set 2 | kurashiki
# Processing Record 5 of Set 2 | aracruz
# Processing Record 6 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 2 | acarau
# Processing Record 8 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 10 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 11 of Set 2 | beringovskiy
# Processing Record 12 of Set 2 | the valley
# Processing Record 13 of Set 2 | pozo colorado
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | oussouye
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | nueve de julio
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | rorvik
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | lazne bohdanec
# Processing Record 24 of Set 2 | imphal
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | riyadh
# Processing Record 27 of Set 2 | srednekolymsk
# Processing Record 28 of Set 2 | tumkur
# Processing Record 29 of Set 2 | shingu
# Processing Record 30 of Set 2 | aleksandrovskoye
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | kaeo
# Processing Record 36 of Set 2 | nehe
# Processing Record 37 of Set 2 | malindi
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set
of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 4 | general cepeda
# Processing Record 7 of Set 4 | richards bay
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | xai-xai
# Processing Record 10 of Set 4 | qasigiannguit
# Processing Record 11 of Set 4 | mbandaka
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | airdrie
# Processing Record 14 of Set 4 | semey
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | porosozero
# Processing Record 18 of Set 4 | tupa
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | san cristobal
# Processing Record 22 of Set 4 | jorpeland
# Processing Record 23 of Set 4 | goderich
# Processing Record 24 of Set 4 | arawa
# Processing Record 25 of Set 4 | fort nelson
# Processing Record 26 of Set 4 | majholi
# Processing Record 27 of Set 4 | kuching
# Processing Record 28 of Set 4 | viedma
# Processing Record 29 of Set 4 | barinitas
# Processing Record 30 of Set 4 | riviere-au-renard
# Processing Record 31 of Set 4 | coquimbo
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | mogadishu
# Processing Record 34 of Set 4 | sao geraldo do araguaia
# Processing Record 35 of Set 4 | katherine
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | presidente bernardes
# Processing Record 38 of Set 4 | saint-francois
# Processing Record 39 of Set 4 | desbiens
# Processing Record 40 of Set 4 | weihe
# Processing Record 41 of Set 4 | buraydah
# Processing Record 42 of Set 4 | mareeba
# Processing Record 43 of Set 4 | sobolevo
# Processing Record 44 of Set 4 | nanortalik
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | allapalli
# Processing Record 47 of Set 4 | thompson
# Processing Record 48 of Set 4 | coihaique
# Processing Record 49 of Set 4 | west bay
# Processing Record 50 of Set 4 | ningan
# City not found. Skipping...
# Processing Record 1 of Set 5 | eskil
# Processing Record 2 of Set 5 | ouallam
# Processing Record 3 of Set 5 | klaksvik
# Processing Record 4 of Set 5 | kencong
# Processing Record 5 of Set 5 | djibo
# Processing Record 6 of Set 5 | ambovombe
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | sibolga
# Processing Record 9 of Set 5 | san miguel
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | mayo
# Processing Record 12 of Set 5 | port lincoln
# Processing Record 13 of Set 5 | porto walter
# Processing Record 14 of Set 5 | olafsvik
# Processing Record 15 of Set 5 | quelimane
# Processing Record 16 of Set 5 | lovozero
# Processing Record 17 of Set 5 | scarborough
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | posadas
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | sehithwa
# Processing Record 22 of Set 5 | catio
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | plouzane
# Processing Record 25 of Set 5 | tarrafal
# Processing Record 26 of Set 5 | merrill
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | iracoubo
# Processing Record 29 of Set 5 | puerto ayora
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | luganville
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 5 | skibbereen
# Processing Record 37 of Set 5 | khatanga
# Processing Record 38 of Set 5 | fuyu
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | honningsvag
# Processing Record 41 of Set 5 | cayenne
# Processing Record 42 of Set 5 | lalibela
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | roura
# Processing Record 45 of Set 5 | saskylakh
# Processing Record 46 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | faya
# Processing Record 48 of Set 5 | dmytrivka
# Processing Record 49 of Set 5 | los llanos de aridane
# Processing Record 50 of Set 5 | vardo
# Processing Record 1 of Set 6 | kahului
# Processing Record 2 of Set 6 | kasongo-lunda
# Processing Record 3 of Set 6 | nador
# Processing Record 4 of Set 6 | kieta
# Processing Record 5 of Set 6 | selishche
# Processing Record 6 of Set 6 | ucluelet
# Processing Record 7 of Set 6 | mahebourg
# Processing Record 8 of Set 6 | malanje
# Processing Record 9 of Set 6 | male
# Processing Record 10 of Set 6 | dikson
# Processing Record 11 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 12 of Set 6 | mende
# Processing Record 13 of Set 6 | paralimni
# Processing Record 14 of Set 6 | bangsund
# Processing Record 15 of Set 6 | svetlogorsk
# Processing Record 16 of Set 6 | hun
# Processing Record 17 of Set 6 | naberera
# Processing Record 18 of Set 6 | derzhavinsk
# Processing Record 19 of Set 6 | walvis bay
# Processing Record 20 of Set 6 | sovetskiy
# Processing Record 21 of Set 6 | olinda
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | oriximina
# Processing Record 24 of Set 6 | yithion
# City not found. Skipping...
# Processing Record 25 of Set 6 | maralal
# Processing Record 26 of Set 6 | vanimo
# Processing Record 27 of Set 6 | funchal
# Processing Record 28 of Set 6 | piacabucu
# Processing Record 29 of Set 6 | tilichiki
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | erzin
# Processing Record 32 of Set 6 | hamada
# Processing Record 33 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 6 | porto novo
# Processing Record 35 of Set 6 | omaruru
# Processing Record 36 of Set 6 | imuris
# Processing Record 37 of Set 6 | batticaloa
# Processing Record 38 of Set 6 | maniitsoq
# Processing Record 39 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | kurumkan
# Processing Record 43 of Set 6 | san carlos de bariloche
# Processing Record 44 of Set 6 | balkhash
# Processing Record 45 of Set 6 | hailey
# Processing Record 46 of Set 6 | sanbu
# Processing Record 47 of Set 6 | bubaque
# Processing Record 48 of Set 6 | ramanuj ganj
# Processing Record 49 of Set 6 | jalu
# Processing Record 50 of Set 6 | ejura
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | buchanan
# Processing Record 3 of Set 7 | merauke
# Processing Record 24 of Set 8 | lafia
# Processing Record 25 of Set 8 | preston
# Processing Record 26 of Set 8 | harper
# Processing Record 27 of Set 8 | berbera
# Processing Record 28 of Set 8 | san vicente
# Processing Record 29 of Set 8 | voghera
# Processing Record 30 of Set 8 | santa rosa
# Processing Record 31 of Set 8 | rosarito
# Processing Record 32 of Set 8 | new waterford
# Processing Record 33 of Set 8 | berezovyy
# Processing Record 34 of Set 8 | pisco
# Processing Record 35 of Set 8 | falam
# Processing Record 36 of Set 8 | ilek
# Processing Record 37 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 8 | balaipungut
# Processing Record 39 of Set 8 | halifax
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | sinnamary
# Processing Record 42 of Set 8 | korla
# Processing Record 43 of Set 8 | bosorod
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | pauini
# Processing Record 46 of Set 8 | kamaishi
# Processing Record 47 of Set 8 | padang
# Processing Record 48 of Set 8 | mount gambier
# Processing Record 49 of Set 8 | bystryy istok
# Processing Record 50 of Set 8 | bandarbeyla
# Processing Record 1 of Set 9 | fehergyarmat
# Processing Record 2 of Set 9 | plettenberg bay
# Processing Record 3 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 9 | barberton
# Processing Record 5 of Set 9 | pyinmana
# Processing Record 6 of Set 9 | vao
# Processing Record 7 of Set 9 | manavalakurichi
# Processing Record 8 of Set 9 | wewak
# Processing Record 9 of Set 9 | komsomolskiy
# Processing Record 10 of Set 9 | gazojak
# Processing Record 11 of Set 9 | boutersem
# Processing Record 12 of Set 9 | aripuana
# Processing Record 13 of Set 9 | bulgan
# Processing Record 14 of Set 9 | vidalia
# Processing Record 15 of Set 9 | chuy
# Processing Record 16 of Set 9 | kavaratti
# Processing Record 17 of Set 9 | karaton
# Processing Record 18 of Set 9 | roebourne
# Processing Record 19 of Set 9 | arlit
# Processing Record 20 of Set 9 | keuruu
# Processing Record 21 of Set 9 | kakanj
# Processing Record 22 of Set 9 | ferrol
# Processing Record 23 of Set 9 | havre-saint-pierre
# Processing Record 24 of Set 9 | dir
# Processing Record 25 of Set 9 | kosh-agach
# Processing Record 26 of Set 9 | diamantino
# Processing Record 27 of Set 9 | vila
# Processing Record 28 of Set 9 | lapinig
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 32 of Set 9 | darhan
# Processing Record 33 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 9 | murray bridge
# Processing Record 35 of Set 9 | tecoanapa
# Processing Record 36 of Set 9 | nieves
# Processing Record 37 of Set 9 | eureka
# Processing Record 38 of Set 9 | asau
# Processing Record 39 of Set 9 | griffith
# Processing Record 40 of Set 9 | palmer
# Processing Record 41 of Set 9 | krasnoselkup
# Processing Record 42 of Set 9 | khani
# Processing Record 43 of Set 9 | saint-pierre
# Processing Record 44 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 9 | byron bay
# Processing Record 46 of Set 9 | nizhnyaya omka
# Processing Record 47 of Set 9 | dabou
# Processing Record 48 of Set 9 | basqal
# Processing Record 49 of Set 9 | charters towers
# Processing Record 50 of Set 9 | wenatchee
# Processing Record 1 of Set 10 | artyom
# Processing Record 2 of Set 10 | nelson bay
# Processing Record 3 of Set 10 | montepuez
# Processing Record 4 of Set 10 | victor harbor
# Processing Record 5 of Set 10 | axim
# Processing Record 6 of Set 10 | skhisma
# Processing Record 7 of Set 10 | baft
# Processing Record 8 of Set 10 | kokopo
# Processing Record 9 of Set 10 | mbini
# Processing Record 10 of Set 10 | sangar
# Processing Record 11 of Set 10 | barreirinha
# Processing Record 12 of Set 10 | lhokseumawe
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | miramar
# Processing Record 15 of Set 10 | mkushi
# Processing Record 16 of Set 10 | laramie
# Processing Record 17 of Set 10 | lacombe
# Processing Record 18 of Set 10 | kupang
# Processing Record 19 of Set 10 | casper
# Processing Record 20 of Set 10 | japura
# Processing Record 21 of Set 10 | gravdal
# Processing Record 22 of Set 10 | arari
# Processing Record 23 of Set 10 | mopti
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | fort saint james
# Processing Record 26 of Set 10 | burgos
# Processing Record 27 of Set 10 | bathsheba
# Processing Record 28 of Set 10 | ust-tsilma
# Processing Record 29 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 30 of Set 10 | poum
# Processing Record 31 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 32 of Set 10 | bay roberts
# Processing Record 33 of Set 10 | dongli
# Processing Record 34 of Set 10 | syntul
# Processing Record 35 of Set 10 | svarstad
# Processing Record 36 of Set 10 | petrokamenskoye
# Processing Record 37 of Set 10 | esperance
# Processing Record 38 of Set 10 | civitanova marche
# Processing Record 39 of Set 10 | ust-kuyga
# Processing Record 40 of Set 10 | asfi
# Processing Record 41 of Set 10 | yulara
# Processing Record 42 of Set 10 | turan
# Processing Record 43 of Set 10 | fukuma
# Processing Record 44 of Set 10 | lavrentiya
# Processing Record 45 of Set 10 | moree
# Processing Record 46 of Set 10 | salinopolis
# Processing Record 47 of Set 10 | puerto princesa
# Processing Record 48 of Set 10 | panama city
# Processing Record 49 of Set 10 | deloraine
# Processing Record 50 of Set 10 | ilulissat
# Processing Record 1 of Set 11 | nazare
# Processing Record 2 of Set 11 | tekeli
# Processing Record 3 of Set 11 | erenhot
# Processing Record 4 of Set 11 | deputatskiy
# Processing Record 5 of Set 11 | bela vista
# Processing Record 6 of Set 11 | mae sai
# Processing Record 7 of Set 11 | lloydminster
# Processing Record 8 of Set 11 | tczew
# Processing Record 9 of Set 11 | kralendijk
# Processing Record 10 of Set 11 | mutum
# Processing Record 11 of Set 11 | iqaluit
# Processing Record 12 of Set 11 | parubcan
# City not found. Skipping...
# Processing Record 13 of Set 11 | rincon
# Processing Record 14 of Set 11 | porto velho
# Processing Record 15 of Set 11 | alwaye
# Processing Record 16 of Set 11 | domoni
# Processing Record 17 of Set 11 | mahibadhoo
# Processing Record 18 of Set 11 | yerbogachen
# Processing Record 19 of Set 11 | kyzyl-suu
# Processing Record 20 of Set 11 | dong hoi
# Processing Record 21 of Set 11 | anderson
# Processing Record 22 of Set 11 | ancud
# Processing Record 23 of Set 11 | boyolangu
# Processing Record 24 of Set 11 | jiuquan
# Processing Record 25 of Set 11 | bereda
# Processing Record 26 of Set 11 | izumo
# Processing Record 27 of Set 11 | caravelas
# Processing Record 28 of Set 11 | saint-augustin
# Processing Record 29 of Set 11 | ossora
# Processing Record 30 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 11 | kroya
# Processing Record 32 of Set 11 | horodnytsya
# Processing Record 33 of Set 11 | portland
# Processing Record 34 of Set 11 | emure
# Processing Record 35 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 11 | roma
# Processing Record 37 of Set 11 | westport
# Processing Record 38 of Set 11 | manzil salim
# Processing Record 39 of Set 11 | liverpool
# Processing Record 40 of Set 11 | barsovo
# Processing Record 41 of Set 11 | pakwach
# City not found. Skipping...
# Processing Record 42 of Set 11 | kruisfontein
# Processing Record 43 of Set 11 | xuddur
# Processing Record 44 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 45 of Set 11 | russell
# Processing Record 46 of Set 11 | touros
# Processing Record 47 of Set 11 | maues
# Processing Record 48 of Set 11 | havelock
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | upata
# Processing Record 1 of Set 12 | mayskiy
# Processing Record 2 of Set 12 | itaqui
# Processing Record 3 of Set 12 | lao cai
# Processing Record 4 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 12 | morro bay
# Processing Record 6 of Set 12 | kouango
# Processing Record 7 of Set 12 | tuktoyaktuk
# Processing Record 8 of Set 12 | neryungri
# Processing Record 9 of Set 12 | acajutla
# Processing Record 10 of Set 12 | istanbul
# Processing Record 11 of Set 12 | athabasca
# Processing Record 12 of Set 12 | shache
# Processing Record 13 of Set 12 | san quintin
# Processing Record 14 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 12 | isangel
# Processing Record 16 of Set 12 | camacha
# Processing Record 17 of Set 12 | inirida
# Processing Record 18 of Set 12 | port hedland
# Processing Record 19 of Set 12 | magdagachi
# Processing Record 20 of Set 12 | tynda
# Processing Record 21 of Set 12 | codrington
# Processing Record 22 of Set 12 | kirakira
# Processing Record 23 of Set 12 | marquette
# Processing Record 24 of Set 12 | vizimyary
# City not found. Skipping...
# Processing Record 25 of Set 12 | aksarka
# Processing Record 26 of Set 12 | qaqortoq
# Processing Record 27 of Set 12 | egvekinot
# Processing Record 28 of Set 12 | chiredzi
# Processing Record 29 of Set 12 | jizan
# Processing Record 30 of Set 12 | sao jose da coroa grande
# Processing Record 31 of Set 12 | samoded
# Processing Record 32 of Set 12 | eydhafushi
# Processing Record 33 of Set 12 | meulaboh
# Processing Record 34 of Set 12 | sorong
# Processing Record 35 of Set 12 | beisfjord
# Processing Record 36 of Set 12 | utiel
# Processing Record 37 of Set 12 | antalaha
# Processing Record 38 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | algiers
# Processing Record 41 of Set 12 | pringsewu
# Processing Record 42 of Set 12 | tarko-sale
# Processing Record 43 of Set 12 | dunedin
# Processing Record 44 of Set 12 | kondopoga
# Processing Record 45 of Set 12 | grand gaube
# Processing Record 46 of Set 12 | chardara
# Processing Record 47 of Set 12 | oranjestad
# Processing Record 48 of Set 12 | kenitra
# Processing Record 49 of Set 12 | karratha
# Processing Record 50 of Set 12 | lorengau
# Processing Record 1 of Set 13 | moerai
# Processing Record 2 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 13 | requena
# Processing Record 4 of Set 13 | lovington
# Processing Record 5 of Set 13 | inuyama
# Processing Record 6 of Set 13 | yar-sale
# Processing Record 7 of Set 13 | la rioja
# Processing Record 8 of Set 13 | hastings
# Processing Record 9 of Set 13 | santa barbara
# Processing Record 10 of Set 13 | grindavik
# Processing Record 11 of Set 13 | chojnow
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities

number_cities = len(city_data)
number_cities
# Out:
# 562

# %%
# Convert the array of dictionaries to a Pandas Dataframe

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Troitsko-Pechorsk  62.7084   56.1964     44.49        86         100
# 1             Bethel  41.3712  -73.4140     84.36        63           0
# 2         Butaritari   3.0707  172.7902     81.91        77          24
# 3            Mataura -46.1927  168.8643     52.48        66          14
# 4            Shimoda  34.6667  138.9500     80.53        87          57
#
#    Wind Speed Country                 Date
# 0        5.64      RU  2022-08-30 22:21:19
# 1        9.22      US  2022-08-30 22:21:20
# 2       18.88      KI  2022-08-30 22:21:20
# 3        4.32      NZ  2022-08-30 22:21:20
# 4        4.97      JP  2022-08-30 22:21:21

# %%
# Reorder the columns

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0  Troitsko-Pechorsk      RU  2022-08-30 22:21:19  62.7084   56.1964
# 1             Bethel      US  2022-08-30 22:21:20  41.3712  -73.4140
# 2         Butaritari      KI  2022-08-30 22:21:20   3.0707  172.7902
# 3            Mataura      NZ  2022-08-30 22:21:20 -46.1927  168.8643
# 4            Shimoda      JP  2022-08-30 22:21:21  34.6667  138.9500
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     44.49        86         100        5.64
# 1     84.36        63           0        9.22
# 2     81.91        77          24       18.88
# 3     52.48        66          14        4.32
# 4     80.53        87          57        4.97

# %%
# Create the output file(CSV)

output_data_file = "weather_data/cities.csv"

# Export the City_Data in a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today = time.strftime("%x")
today
# Out:
# '08/30/22'

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig1.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig3.png")

#Show plot
plt.show()

# %%
# Import time module

import time

# Build the scatter plot for latitude vs max temperature

plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties

plt.title(f"City Latitude vs Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig4.png")

#Show plot
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Call the loc function

index13 = city_data_df.loc[13]
